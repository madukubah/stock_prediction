# 2016-12-09  109.179115
# 2016-12-12  108.556305
# 2016-12-13  110.367195
# 2016-12-14  110.367195
# 2016-12-15  110.970810
# 2016-12-16  111.114532
# 2016-12-19  111.756470
# 2016-12-20  112.053490
# 2016-12-21  112.158890
# 2016-12-22  111.421135
# 2016-12-23  111.641487
# 2016-12-27  112.350517
# 2016-12-28  111.871452
# 2016-12-29  111.842705
# 2016-12-30  110.970810
# 2017-01-03  111.286987
# 2017-01-04  111.162437
# 2017-01-05  111.727715
# 2017-01-06  112.973305
# 2017-01-09  114.008080
# 2017-01-10  114.123047
# 2017-01-11  114.736275
#
# [1770 rows x 6 columns]

# %%
mavg
# Out:
# Date
# 2009-12-31           NaN
# 2010-01-04           NaN
# 2010-01-05           NaN
# 2010-01-06           NaN
# 2010-01-07           NaN
# 2010-01-08           NaN
# 2010-01-11           NaN
# 2010-01-12           NaN
# 2010-01-13           NaN
# 2010-01-14           NaN
# 2010-01-15           NaN
# 2010-01-19           NaN
# 2010-01-20           NaN
# 2010-01-21           NaN
# 2010-01-22           NaN
# 2010-01-25           NaN
# 2010-01-26           NaN
# 2010-01-27           NaN
# 2010-01-28           NaN
# 2010-01-29           NaN
# 2010-02-01           NaN
# 2010-02-02           NaN
# 2010-02-03           NaN
# 2010-02-04           NaN
# 2010-02-05           NaN
# 2010-02-08           NaN
# 2010-02-09           NaN
# 2010-02-10           NaN
# 2010-02-11           NaN
# 2010-02-12           NaN
#                  ...
# 2016-11-29    104.183044
# 2016-11-30    104.322503
# 2016-12-01    104.447920
# 2016-12-02    104.582481
# 2016-12-05    104.691269
# 2016-12-06    104.808200
# 2016-12-07    104.925524
# 2016-12-08    105.052913
# 2016-12-09    105.196981
# 2016-12-12    105.339847
# 2016-12-13    105.508122
# 2016-12-14    105.688912
# 2016-12-15    105.882091
# 2016-12-16    106.017166
# 2016-12-19    106.145482
# 2016-12-20    106.278000
# 2016-12-21    106.394127
# 2016-12-22    106.517762
# 2016-12-23    106.631180
# 2016-12-27    106.745493
# 2016-12-28    106.839668
# 2016-12-29    106.925071
# 2016-12-30    106.997562
# 2017-01-03    107.080935
# 2017-01-04    107.163730
# 2017-01-05    107.249795
# 2017-01-06    107.335924
# 2017-01-09    107.433354
# 2017-01-10    107.533458
# 2017-01-11    107.641030
# Name: Adj Close, Length: 1770, dtype: float64

# %%
close_px = df['Adj Close']
mavg = close_px.rolling(window=100).mean()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import style

# Adjusting the size of matplotlib
import matplotlib as mpl
mpl.rc('figure', figsize=(8, 7))
mpl.__version__

# Adjusting the style of matplotlib
style.use('ggplot')

close_px.plot(label='AAPL')
mavg.plot(label='mavg')
plt.legend()

# %%
rets = close_px / close_px.shift(1) - 1
rets.plot(label='return')

# %%
dfcomp = web.DataReader(['AAPL', 'GE', 'GOOG', 'IBM', 'MSFT'],'yahoo',start=start,end=end)['Adj Close']

# %%
dfcomp
# Out:
# Symbols           AAPL         GE        GOOG         IBM       MSFT
# Date
# 2009-12-31   26.272409  10.669474  308.832428   96.994438  24.072418
# 2010-01-04   26.681330  10.895131  312.204773   98.142967  24.443624
# 2010-01-05   26.727465  10.951548  310.829926   96.957375  24.451517
# 2010-01-06   26.302330  10.895131  302.994293   96.327530  24.301458
# 2016-12-23  111.641487  28.299286  789.909973  148.243713  60.124058
# 2016-12-27  112.350517  28.317036  791.549988  148.626038  60.162071
# 2016-12-28  111.871452  28.139500  785.049988  147.781281  59.886375
# 2016-12-29  111.842705  28.148375  782.789978  148.145859  59.800812
# 2016-12-30  110.970810  28.050728  771.820007  147.603439  59.078251
# 2017-01-03  111.286987  28.130621  786.140015  148.670532  59.496574
# 2017-01-04  111.162437  28.139500  786.900024  150.511230  59.230362
# 2017-01-05  111.727715  27.979715  794.020020  150.013260  59.230362
# 2017-01-06  112.973305  28.059608  806.150024  150.751312  59.743763
# 2017-01-09  114.008080  27.926458  806.650024  149.079559  59.553616
# 2017-01-10  114.123047  27.846561  804.789978  147.185501  59.534603
# 2017-01-11  114.736275  27.935333  807.909973  149.168472  60.076519
#
# [1770 rows x 5 columns]

# %%
retscomp = dfcomp.pct_change()

corr = retscomp.corr()

# %%
corr
# Out:
# Symbols      AAPL        GE      GOOG       IBM      MSFT
# Symbols
# AAPL     1.000000  0.381925  0.411879  0.384136  0.393774
# GE       0.381925  1.000000  0.422535  0.535506  0.474491
# GOOG     0.411879  0.422535  1.000000  0.403215  0.472263
# IBM      0.384136  0.535506  0.403215  1.000000  0.496951
# MSFT     0.393774  0.474491  0.472263  0.496951  1.000000

# %%
plt.scatter(retscomp.AAPL, retscomp.GE)
plt.xlabel("Returns AAPL")
plt.ylabel("Returns GE")
# Out:
# Text(0, 0.5, 'Returns GE')

# %%
pd.scatter_matrix(retscomp, diagonal='kde', figsize=(10, 10));
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-f560006adb3a> in <module>
# ----> 1 pd.scatter_matrix(retscomp, diagonal='kde', figsize=(10, 10));
#
# AttributeError: module 'pandas' has no attribute 'scatter_matrix'

# %%
pd.scatter_matrix(retscomp, diagonal='kde', figsize=(10, 10));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f560006adb3a> in <module>
# ----> 1 pd.scatter_matrix(retscomp, diagonal='kde', figsize=(10, 10));
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import datetime
import pandas_datareader.data as web
from pandas import Series, DataFrame

# %%
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2017, 1, 11)

df = web.DataReader("AAPL", 'yahoo', start, end)
dfcomp = web.DataReader(['AAPL', 'GE', 'GOOG', 'IBM', 'MSFT'],'yahoo',start=start,end=end)['Adj Close']

# %%
retscomp = dfcomp.pct_change()

corr = retscomp.corr()

# %%
pd.scatter_matrix(retscomp, diagonal='kde', figsize=(10, 10));
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-f560006adb3a> in <module>
# ----> 1 pd.scatter_matrix(retscomp, diagonal='kde', figsize=(10, 10));
#
# AttributeError: module 'pandas' has no attribute 'scatter_matrix'

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(retscomp, diagonal='kde', figsize=(10, 10));

# %%
retscomp
# Out:
# Symbols         AAPL        GE      GOOG       IBM      MSFT
# Date
# 2009-12-31       NaN       NaN       NaN       NaN       NaN
# 2010-01-04  0.015565  0.021150  0.010920  0.011841  0.015420
# 2010-01-05  0.001729  0.005178 -0.004404 -0.012080  0.000323
# 2010-01-06 -0.015906 -0.005151 -0.025209 -0.006496 -0.006137
# 2010-01-07 -0.001849  0.051780 -0.023280 -0.003461 -0.010400
# 2010-01-08  0.006648  0.021539  0.013331  0.010035  0.006897
# 2016-12-22 -0.006578 -0.002195 -0.004153 -0.001614  0.000157
# 2016-12-23  0.001978  0.001886 -0.001706 -0.002095 -0.004878
# 2016-12-27  0.006351  0.000627  0.002076  0.002579  0.000632
# 2016-12-28 -0.004264 -0.006270 -0.008212 -0.005684 -0.004583
# 2016-12-29 -0.000257  0.000315 -0.002879  0.002467 -0.001429
# 2016-12-30 -0.007796 -0.003469 -0.014014 -0.003661 -0.012083
# 2017-01-03  0.002849  0.002848  0.018554  0.007229  0.007081
# 2017-01-04 -0.001119  0.000316  0.000967  0.012381 -0.004474
# 2017-01-05  0.005085 -0.005678  0.009048 -0.003309  0.000000
# 2017-01-06  0.011148  0.002855  0.015277  0.004920  0.008668
# 2017-01-09  0.009159 -0.004745  0.000620 -0.011089 -0.003183
# 2017-01-10  0.001008 -0.002861 -0.002306 -0.012705 -0.000319
# 2017-01-11  0.005373  0.003188  0.003877  0.013473  0.009103
#
# [1770 rows x 5 columns]

# %%
plt.scatter(retscomp.AAPL, retscomp.GE)
plt.xlabel("Returns AAPL")
plt.ylabel("Returns GE")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-efd8908142fe> in <module>
# ----> 1 plt.scatter(retscomp.AAPL, retscomp.GE)
#       2 plt.xlabel("Returns AAPL")
#       3 plt.ylabel("Returns GE")
#
# NameError: name 'plt' is not defined

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import style

# Adjusting the size of matplotlib
import matplotlib as mpl
mpl.rc('figure', figsize=(8, 7))
mpl.__version__

# Adjusting the style of matplotlib
style.use('ggplot')

close_px.plot(label='AAPL')
mavg.plot(label='mavg')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-9e645f1941c9> in <module>
#      11 style.use('ggplot')
#      12
# ---> 13 close_px.plot(label='AAPL')
#      14 mavg.plot(label='mavg')
#      15 plt.legend()
#
# NameError: name 'close_px' is not defined

# %%
close_px = df['Adj Close']
mavg = close_px.rolling(window=100).mean()

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import style

# Adjusting the size of matplotlib
import matplotlib as mpl
mpl.rc('figure', figsize=(8, 7))
mpl.__version__

# Adjusting the style of matplotlib
style.use('ggplot')

close_px.plot(label='AAPL')
mavg.plot(label='mavg')
plt.legend()

# %%
plt.scatter(retscomp.AAPL, retscomp.GE)
plt.xlabel("Returns AAPL")
plt.ylabel("Returns GE")
# Out:
# Text(0, 0.5, 'Returns GE')

# %%
scatter_matrix(retscomp, diagonal='kde', figsize=(10, 10));

# %%
plt.imshow(corr, cmap='hot', interpolation='none')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns)
plt.yticks(range(len(corr)), corr.columns);

# %%
plt.scatter(retscomp.mean(), retscomp.std())
plt.xlabel('Expected returns')
plt.ylabel('Risk')
for label, x, y in zip(retscomp.columns, retscomp.mean(), retscomp.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

# %%
dfreg = df.loc[:,["Adj Close","Volume"]]
dfreg["HL_PCT"] = (df["High"] — df["Low"]) / df["Close"] * 100.0
dfreg["PCT_change"] = (df["Close"] — df["Open"]) / df["Open"] * 100.0
# Out:
#   File "<ipython-input-17-32cb8fb223cd>", line 2
#     dfreg["HL_PCT"] = (df["High"] — df["Low"]) / df["Close"] * 100.0
#                                   ^
# SyntaxError: invalid character in identifier

# %%
dfreg = df.loc[:,["Adj Close","Volume"]]
dfreg["HL_PCT"] = (df["High"] - df["Low"]) / df["Close"] * 100.0
dfreg["PCT_change"] = (df["Close"] - df["Open"]) / df["Open"] * 100.0

# %%
dfreg["PCT_change"]
# Out:
# Date
# 2009-12-31   -1.126074
# 2010-01-04    0.271752
# 2010-01-05   -0.102519
# 2010-01-06   -1.590633
# 2010-01-07   -0.552538
# 2010-01-08    0.798864
# 2010-01-11   -1.264095
# 2010-01-12   -0.702707
# 2010-01-13    1.337373
# 2010-01-14   -0.323641
# 2010-01-15   -2.370452
# 2010-01-19    3.220848
# 2010-01-20   -1.479692
# 2010-01-21   -1.890795
# 2010-01-22   -4.366963
# 2010-01-25    0.276529
# 2010-01-26   -0.004856
# 2010-01-27    0.497950
# 2010-01-28   -2.752164
# 2010-01-29   -4.485773
# 2010-02-01    1.226803
# 2010-02-02   -0.025523
# 2010-02-03    2.080238
# 2010-02-04   -2.378895
# 2010-02-05    1.469137
# 2010-02-08   -0.802294
# 2010-02-09   -0.117092
# 2010-02-10   -0.393073
# 2010-02-11    1.944783
# 2010-02-12    1.145827
#                 ...
# 2016-11-29    0.613829
# 2016-11-30   -0.967744
# 2016-12-01   -0.797323
# 2016-12-02    0.668685
# 2016-12-05   -0.809090
# 2016-12-06    0.410956
# 2016-12-07    1.619986
# 2016-12-08    1.136571
# 2016-12-09    1.460243
# 2016-12-12    0.008829
# 2016-12-13    1.185880
# 2016-12-14    0.130391
# 2016-12-15    0.381351
# 2016-12-16   -0.429295
# 2016-12-19    0.725385
# 2016-12-20    0.179886
# 2016-12-21    0.222598
# 2016-12-22   -0.051566
# 2016-12-23    0.804568
# 2016-12-27    0.635089
# 2016-12-28   -0.646694
# 2016-12-29    0.240452
# 2016-12-30   -0.711532
# 2017-01-03    0.302244
# 2017-01-04    0.146740
# 2017-01-05    0.595240
# 2017-01-06    0.967636
# 2017-01-09    0.881730
# 2017-01-10    0.286271
# 2017-01-11    0.850600
# Name: PCT_change, Length: 1770, dtype: float64

# %%
# Drop missing value
dfreg.fillna(value=-99999, inplace=True)
# We want to separate 1 percent of the data to forecast
forecast_out = int(math.ceil(0.01 * len(dfreg)))
# Separating the label here, we want to predict the AdjClose
forecast_col = 'Adj Close'
dfreg['label'] = dfreg[forecast_col].shift(-forecast_out)
X = np.array(dfreg.drop(['label'], 1))
# Scale the X so that everyone can have the same distribution for linear regression
X = preprocessing.scale(X)
# Finally We want to find Data Series of late X and early X (train) for model generation and evaluation
X_lately = X[-forecast_out:]
X = X[:-forecast_out]
# Separate label and identify it as y
y = np.array(dfreg['label'])
y = y[:-forecast_out]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c91e23c723f3> in <module>
#       2 dfreg.fillna(value=-99999, inplace=True)
#       3 # We want to separate 1 percent of the data to forecast
# ----> 4 forecast_out = int(math.ceil(0.01 * len(dfreg)))
#       5 # Separating the label here, we want to predict the AdjClose
#       6 forecast_col = 'Adj Close'
#
# NameError: name 'math' is not defined

# %%
import math
# Drop missing value
dfreg.fillna(value=-99999, inplace=True)
# We want to separate 1 percent of the data to forecast
forecast_out = int(math.ceil(0.01 * len(dfreg)))
# Separating the label here, we want to predict the AdjClose
forecast_col = 'Adj Close'
dfreg['label'] = dfreg[forecast_col].shift(-forecast_out)
X = np.array(dfreg.drop(['label'], 1))
# Scale the X so that everyone can have the same distribution for linear regression
X = preprocessing.scale(X)
# Finally We want to find Data Series of late X and early X (train) for model generation and evaluation
X_lately = X[-forecast_out:]
X = X[:-forecast_out]
# Separate label and identify it as y
y = np.array(dfreg['label'])
y = y[:-forecast_out]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-83a67d9de737> in <module>
#       7 forecast_col = 'Adj Close'
#       8 dfreg['label'] = dfreg[forecast_col].shift(-forecast_out)
# ----> 9 X = np.array(dfreg.drop(['label'], 1))
#      10 # Scale the X so that everyone can have the same distribution for linear regression
#      11 X = preprocessing.scale(X)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
# Drop missing value
dfreg.fillna(value=-99999, inplace=True)
# We want to separate 1 percent of the data to forecast
forecast_out = int(math.ceil(0.01 * len(dfreg)))
# Separating the label here, we want to predict the AdjClose
forecast_col = 'Adj Close'
dfreg['label'] = dfreg[forecast_col].shift(-forecast_out)
X = np.array(dfreg.drop(['label'], 1))
# Scale the X so that everyone can have the same distribution for linear regression
X = preprocessing.scale(X)
# Finally We want to find Data Series of late X and early X (train) for model generation and evaluation
X_lately = X[-forecast_out:]
X = X[:-forecast_out]
# Separate label and identify it as y
y = np.array(dfreg['label'])
y = y[:-forecast_out]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-c91e23c723f3> in <module>
#       8 X = np.array(dfreg.drop(['label'], 1))
#       9 # Scale the X so that everyone can have the same distribution for linear regression
# ---> 10 X = preprocessing.scale(X)
#      11 # Finally We want to find Data Series of late X and early X (train) for model generation and evaluation
#      12 X_lately = X[-forecast_out:]
#
# NameError: name 'preprocessing' is not defined

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor

from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
# Drop missing value
dfreg.fillna(value=-99999, inplace=True)
# We want to separate 1 percent of the data to forecast
forecast_out = int(math.ceil(0.01 * len(dfreg)))
# Separating the label here, we want to predict the AdjClose
forecast_col = 'Adj Close'
dfreg['label'] = dfreg[forecast_col].shift(-forecast_out)
X = np.array(dfreg.drop(['label'], 1))
# Scale the X so that everyone can have the same distribution for linear regression
X = preprocessing.scale(X)
# Finally We want to find Data Series of late X and early X (train) for model generation and evaluation
X_lately = X[-forecast_out:]
X = X[:-forecast_out]
# Separate label and identify it as y
y = np.array(dfreg['label'])
y = y[:-forecast_out]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-c91e23c723f3> in <module>
#       8 X = np.array(dfreg.drop(['label'], 1))
#       9 # Scale the X so that everyone can have the same distribution for linear regression
# ---> 10 X = preprocessing.scale(X)
#      11 # Finally We want to find Data Series of late X and early X (train) for model generation and evaluation
#      12 X_lately = X[-forecast_out:]
#
# NameError: name 'preprocessing' is not defined

# %%
from sklearn.preprocessing import preprocessing
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-28-f023063d5a68> in <module>
# ----> 1 from sklearn.preprocessing import preprocessing
#
# ImportError: cannot import name 'preprocessing' from 'sklearn.preprocessing' (C:\Users\alan\Anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
from sklearn import preprocessing as _preprocessing

# %%
# Drop missing value
dfreg.fillna(value=-99999, inplace=True)
# We want to separate 1 percent of the data to forecast
forecast_out = int(math.ceil(0.01 * len(dfreg)))
# Separating the label here, we want to predict the AdjClose
forecast_col = 'Adj Close'
dfreg['label'] = dfreg[forecast_col].shift(-forecast_out)
X = np.array(dfreg.drop(['label'], 1))
# Scale the X so that everyone can have the same distribution for linear regression
X = _preprocessing.scale(X)
# Finally We want to find Data Series of late X and early X (train) for model generation and evaluation
X_lately = X[-forecast_out:]
X = X[:-forecast_out]
# Separate label and identify it as y
y = np.array(dfreg['label'])
y = y[:-forecast_out]

# %%
# Linear regression
clfreg = LinearRegression(n_jobs=-1)
clfreg.fit(X_lately, y)
# Quadratic Regression 2
clfpoly2 = make_pipeline(PolynomialFeatures(2), Ridge())
clfpoly2.fit(X_train, y_train)

# Quadratic Regression 3
clfpoly3 = make_pipeline(PolynomialFeatures(3), Ridge())
clfpoly3.fit(X_lately, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-f81b312c5ca0> in <module>
#       1 # Linear regression
#       2 clfreg = LinearRegression(n_jobs=-1)
# ----> 3 clfreg.fit(X_lately, y)
#       4 # Quadratic Regression 2
#       5 clfpoly2 = make_pipeline(PolynomialFeatures(2), Ridge())
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     764         y = y.astype(np.float64)
#     765
# --> 766     check_consistent_length(X, y)
#     767
#     768     return X, y
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     233     if len(uniques) > 1:
#     234         raise ValueError("Found input variables with inconsistent numbers of"
# --> 235                          " samples: %r" % [int(l) for l in lengths])
#     236
#     237
#
# ValueError: Found input variables with inconsistent numbers of samples: [18, 1752]

# %%
# Linear regression
clfreg = LinearRegression(n_jobs=-1)
clfreg.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=-1, normalize=False)

# %%
clfreg
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=-1, normalize=False)

# %%
# Linear regression
clfreg = LinearRegression(n_jobs=-1)
clfreg.fit(X, y)
# Quadratic Regression 2
clfpoly2 = make_pipeline(PolynomialFeatures(2), Ridge())
clfpoly2.fit(X, y)

# Quadratic Regression 3
clfpoly3 = make_pipeline(PolynomialFeatures(3), Ridge())
clfpoly3.fit(X, y)
# Out:
# Pipeline(memory=None,
#      steps=[('polynomialfeatures', PolynomialFeatures(degree=3, include_bias=True, interaction_only=False)), ('ridge', Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001))])

# %%
# KNN Regression
clfknn = KNeighborsRegressor(n_neighbors=2)
clfknn.fit(X, y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#           weights='uniform')

# %%
confidencereg = clfreg.score(X_test, y_test)
confidencepoly2 = clfpoly2.score(X_test,y_test)
confidencepoly3 = clfpoly3.score(X_test,y_test)
confidenceknn = clfknn.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-b0b2bcac01ad> in <module>
# ----> 1 confidencereg = clfreg.score(X_test, y_test)
#       2 confidencepoly2 = clfpoly2.score(X_test,y_test)
#       3 confidencepoly3 = clfpoly3.score(X_test,y_test)
#       4 confidenceknn = clfknn.score(X_test, y_test)
#
# NameError: name 'X_test' is not defined

# %%
confidencereg = clfreg.score(X, y)
confidencepoly2 = clfpoly2.score(X,y)
confidencepoly3 = clfpoly3.score(X,y)
confidenceknn = clfknn.score(X, y)

# %%
confidencereg
# Out:
# 0.9667514007689056

# %%
forecast_set = clfreg .predict(X_lately)
dfreg['Forecast'] = np.nan

# %%
dfreg['Forecast']
# Out:
# Date
# 2009-12-31   NaN
# 2010-01-04   NaN
# 2010-01-05   NaN
# 2010-01-06   NaN
# 2010-01-07   NaN
# 2010-01-08   NaN
# 2010-01-11   NaN
# 2010-01-12   NaN
# 2010-01-13   NaN
# 2010-01-14   NaN
# 2010-01-15   NaN
# 2010-01-19   NaN
# 2010-01-20   NaN
# 2010-01-21   NaN
# 2010-01-22   NaN
# 2010-01-25   NaN
# 2010-01-26   NaN
# 2010-01-27   NaN
# 2010-01-28   NaN
# 2010-01-29   NaN
# 2010-02-01   NaN
# 2010-02-02   NaN
# 2010-02-03   NaN
# 2010-02-04   NaN
# 2010-02-05   NaN
# 2010-02-08   NaN
# 2010-02-09   NaN
# 2010-02-10   NaN
# 2010-02-11   NaN
# 2010-02-12   NaN
#               ..
# 2016-11-29   NaN
# 2016-11-30   NaN
# 2016-12-01   NaN
# 2016-12-02   NaN
# 2016-12-05   NaN
# 2016-12-06   NaN
# 2016-12-07   NaN
# 2016-12-08   NaN
# 2016-12-09   NaN
# 2016-12-12   NaN
# 2016-12-13   NaN
# 2016-12-14   NaN
# 2016-12-15   NaN
# 2016-12-16   NaN
# 2016-12-19   NaN
# 2016-12-20   NaN
# 2016-12-21   NaN
# 2016-12-22   NaN
# 2016-12-23   NaN
# 2016-12-27   NaN
# 2016-12-28   NaN
# 2016-12-29   NaN
# 2016-12-30   NaN
# 2017-01-03   NaN
# 2017-01-04   NaN
# 2017-01-05   NaN
# 2017-01-06   NaN
# 2017-01-09   NaN
# 2017-01-10   NaN
# 2017-01-11   NaN
# Name: Forecast, Length: 1770, dtype: float64

# %%
last_date = dfreg.iloc[-1].name
last_unix = last_date
next_unix = last_unix + datetime.timedelta(days=1)

for i in forecast_set:
    next_date = next_unix
    next_unix += datetime.timedelta(days=1)
    dfreg.loc[next_date] = [np.nan for _ in range(len(dfreg.columns)-1)]+[i]
dfreg['Adj Close'].tail(500).plot()
dfreg['Forecast'].tail(500).plot()
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
